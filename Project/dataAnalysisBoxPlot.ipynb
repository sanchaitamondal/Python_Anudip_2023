# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataAnalysis=pd.read_excel("dataAnalysis.xlsx", sheet_name='DifferentFormat')
dataAnalysisDf=pd.DataFrame(dataAnalysis)

# %%
dataAnalysisDf
# Out:
#      Team Member  Day       TPT   Quality  Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        Charlie    1  1.968869  91.04835         NaN        NaN        NaN
# 1        Charlie    2  1.929492  91.23045         NaN        NaN        NaN
# 2        Charlie    3  1.890902  91.41291         NaN        NaN        NaN
# 3        Charlie    4  1.910000  91.59574         NaN        NaN        NaN
# 4        Charlie    5  1.890000  91.77893         NaN        NaN        NaN
# ...          ...  ...       ...       ...         ...        ...        ...
# 1045        Biju   26  1.440000  95.62000         NaN        NaN        NaN
# 1046        Biju   27  1.087845  95.00000         NaN        NaN        NaN
# 1047        Biju   28  1.350000  94.50000         NaN        NaN        NaN
# 1048        Biju   29  1.320000  94.32000         NaN        NaN        NaN
# 1049        Biju   30  1.400000  95.65000         NaN        NaN        NaN
#
#      Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# ...

# %%
dataAnalysisDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Team Member  1050 non-null   object
#  1   Day          1050 non-null   int64
#  2   TPT          1050 non-null   float64
#  3   Quality      1050 non-null   float64
#  4   Unnamed: 4   0 non-null      float64
#  5   Unnamed: 5   2 non-null      object
#  6   Unnamed: 6   1 non-null      object
#  7   Unnamed: 7   1 non-null      object
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  2 non-null      float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 90.4+ KB

# %%
dataAnalysis=pd.read_excel("dataAnalysis.xlsx", sheet_name='DifferentFormat')
dataAnalysisDf=pd.DataFrame(dataAnalysis)
dataAnalysisDf.boxplot(column=['TPT'],by=['Team Member'])
plt.title("Boxplot by Team Members")
plt.xticks(rotation=90)
plt.xlabel("Team Members")
plt.ylabel("TPT")
plt.show()
